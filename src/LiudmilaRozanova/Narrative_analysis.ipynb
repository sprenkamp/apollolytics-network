# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
r = pd.read_csv("rmsg_comm.csv")
r
# Out:
# /tmp/ipykernel_7475/4948060.py:1: DtypeWarning: Columns (27,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   r = pd.read_csv("rmsg_comm.csv")
#             chat_id        id                chat_name     peer_id  \
# 0        1872871388   4988378   https://t.me/specchatZ  1872871388
# 1        1872871388   4988380   https://t.me/specchatZ  1872871388
# 2        1872871388   4988384   https://t.me/specchatZ  1872871388
# 3        1872871388   4988385   https://t.me/specchatZ  1872871388
# 4        1872871388   4988386   https://t.me/specchatZ  1872871388
# ...             ...       ...                      ...         ...
# 3048941  1366415996  19037272  https://t.me/readovchat  1366415996
# 3048942  1366415996  19037278  https://t.me/readovchat  1366415996
# 3048943  1366415996  19037285  https://t.me/readovchat  1366415996
# 3048944  1366415996  19037298  https://t.me/readovchat  1366415996
# 3048945  1366415996  19037300  https://t.me/readovchat  1366415996
#
#              messagedatetime messagedate  \
# 0        2024-12-08 11:00:06  2024-12-08
# 1        2024-12-08 11:00:55  2024-12-08
# 2        2024-12-08 11:01:13  2024-12-08
# 3        2024-12-08 11:02:02  2024-12-08
# 4        2024-12-08 11:02:05  2024-12-08
# ...                      ...         ...
# 3048941  2024-12-16 09:16:14  2024-12-16
# 3048942  2024-12-16 09:16:27  2024-12-16
# 3048943  2024-12-16 09:16:38  2024-12-16
# 3048944  2024-12-16 09:17:30  2024-12-16
# 3048945  2024-12-16 09:17:37  2024-12-16
#
#                                                messagetext out mentioned  \
# 0                        Гнида приехала лизать дупу трампу   f         f
# 1                          Да, как все быстро устроили🙈🙈🙈🙈   f         f
# 2        ⚡️ Правила чата:\n\n⚠️ Ссылки и пересылки из д...   f         f
# 3                    Смирись и прими!\nКаждому своё время!   f         f
# 4                              Украину давно желают🙈🙈🙈🙈😡😡😡   f         f
# ...                                                    ...  ..       ...
# 3048941  Раньше отстреливали всех и все, зверье зало, ч...   f         f
# 3048942  Знаю несколько пар, которые не заводят детей т...   f         f
# 3048943  Жилищный вопрос - это только часть проблемы. Я...   f         f
# 3048944  Но от таджиков и негров рожают. Значит нашим м...   f         f
# 3048945  Нарожать то они нарожают, но это будет только ...   f         f
#
#         media_unread  ... post_author grouped_id ttl_period  \
# 0                  f  ...         NaN        NaN        NaN
# 1                  f  ...         NaN        NaN        NaN
# 2                  f  ...         NaN        NaN        NaN
# 3                  f  ...         NaN        NaN        NaN
# 4                  f  ...         NaN        NaN        NaN
# ...              ...  ...         ...        ...        ...
# 3048941            f  ...         NaN        NaN        NaN
# 3048942            f  ...         NaN        NaN        NaN
# 3048943            f  ...         NaN        NaN        NaN
# 3048944            f  ...         NaN        NaN        NaN
# 3048945            f  ...         NaN        NaN        NaN
#
#         quick_reply_shortcut_id effect factcheck views forwards replies  \
# 0                           NaN    NaN       NaN     0        0       0
# 1                           NaN    NaN       NaN     0        0       0
# 2                           NaN    NaN       NaN     0        0       0
# 3                           NaN    NaN       NaN     0        0       0
# 4                           NaN    NaN       NaN     0        0       0
# ...                         ...    ...       ...   ...      ...     ...
# 3048941                     NaN    NaN       NaN     0        0       0
# 3048942                     NaN    NaN       NaN     0        0       0
# 3048943                     NaN    NaN       NaN     0        0       0
# 3048944                     NaN    NaN       NaN     0        0       0
# 3048945                     NaN    NaN       NaN     0        0       0
#
#                 reactions
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 3048941               NaN
# 3048942          {"👍": 1}
# 3048943  {"❤": 2, "🤯": 1}
# 3048944               NaN
# 3048945  {"😁": 1, "🤔": 1}
#
# [3048946 rows x 40 columns]

# %%
def organize_threads(csv_file_path):
    # First pass: read all messages and create message lookup
    messages = {}
    roots = []

    with open(csv_file_path, 'r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            msg_id = row['id']
            chat_id = row['chat_id']
            reply_to = row['reply_to']

            # Create composite key using both chat_id and msg_id
            msg_key = f"{chat_id}_{msg_id}"

            messages[msg_key] = {
                'data': row,
                'children': []
            }

            # If it's a root message (no reply_to)
            if not reply_to:
                roots.append(msg_key)

    # Second pass: build threads by connecting replies
    for msg_key, msg_data in messages.items():
        reply_to = msg_data['data']['reply_to']
        chat_id = msg_data['data']['chat_id']

        if reply_to:
            # Create parent message key using the same chat_id
            parent_key = f"{chat_id}_{reply_to}"
            if parent_key in messages:
                messages[parent_key]['children'].append(msg_key)

    # Helper function to flatten a thread
    def flatten_thread(msg_key):
        thread = [messages[msg_key]['data']]
        for child_key in messages[msg_key]['children']:
            thread.extend(flatten_thread(child_key))
        return thread

    # Build final list of threads
    threads = []
    for root_key in roots:
        thread = flatten_thread(root_key)
        threads.append(thread)

    return threads

# %%
threads = organize_threads('rmsg_comm.csv')

# %%
def create_thread_summary_df_optimized(threads):
    thread_summaries = []

    for thread in threads:
        if not thread:
            continue

        root_message = thread[0]
        root_id = root_message['id']

        # Create a message lookup dictionary for this thread
        msg_depths = {root_id: 0}  # Root has depth 0
        max_depth = 0

        # Single pass through messages to calculate depths
        for msg in thread[1:]:  # Skip root message
            reply_to = msg['reply_to']
            if reply_to in msg_depths:
                depth = msg_depths[reply_to] + 1
                msg_depths[msg['id']] = depth
                max_depth = max(max_depth, depth)

        thread_summary = {
            'root_id': root_id,
            'messagetext': root_message.get('messagetext', ''),
            'chat_name': root_message.get('chat_name', ''),
            'thread_size': len(thread),
            'max_depth': max_depth
        }
        thread_summaries.append(thread_summary)

    return pd.DataFrame(thread_summaries)

# %%
df = create_thread_summary_df_optimized(threads)
df = df.sort_values('thread_size', ascending=False)
df
# Out:
#          root_id                                        messagetext  \
# 262539  18081366  На М-12 водитель фуры резко перестроился в лев...
# 341869  18926209  В Дзержинске школьницы дважды впечатали учител...
# 262435  18048844  Жители Химок несколько лет терпят запах гнили ...
# 202558  18259811  Проректор Финансового Университета Зубец предл...
# 341801  18900319  Тот самый 14-летний чеченец, за которого накан...
# ...          ...                                                ...
# 130109    176821                                             Добрый
# 130111    176850  Бля, я сейчас чувствую себя старой. Почему на вы🙄
# 130112    176856                                                 🤣🤣
# 130114    176880                                                  😳
# 175982     11876                                        Незнаю куда
#
#                                  chat_name  thread_size  max_depth
# 262539             https://t.me/readovchat         2777         33
# 341869             https://t.me/readovchat         2489         22
# 262435             https://t.me/readovchat         2437         10
# 202558             https://t.me/readovchat         2266         21
# 341801             https://t.me/readovchat         2255         26
# ...                                    ...          ...        ...
# 130109  https://t.me/incident_kuzbass_chat            1          0
# 130111  https://t.me/incident_kuzbass_chat            1          0
# 130112  https://t.me/incident_kuzbass_chat            1          0
# 130114  https://t.me/incident_kuzbass_chat            1          0
# 175982             https://t.me/svodkadnrr            1          0
#
# [342153 rows x 5 columns]

# %%
def plot_thread_density_simple(thread, interval_minutes=10):
    # Clear any existing plots
    plt.clf()

    df = pd.DataFrame(thread)
    df['timestamp'] = pd.to_datetime(df['messagedatetime'])

    counts = df.resample(f'{interval_minutes}min', on='timestamp').size()

    # Create a new figure
    fig = plt.figure(figsize=(15, 7))

    plt.plot(counts.index, counts.values, '-', linewidth=2)

    plt.title(f'Comment Density Over Time\n'
              f'Thread started: {df.timestamp.min().strftime("%Y-%m-%d %H:%M:%S")}\n'
              f'Total messages: {len(thread)}, Interval: {interval_minutes} minutes')

    plt.xlabel('Time')
    plt.ylabel('Number of comments')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.gcf().autofmt_xdate()
    plt.tight_layout()

    # Close the figure to prevent display
    plt.close()

    return fig

# %%
sorted_threads = sorted(threads, key=len, reverse=True)

# %%
fig = plot_thread_density_simple(sorted_threads[0][:500], interval_minutes=5)
fig

# %%
len(threads[0])
# Out:
# 50

# %%
def flatten_threads_to_df(threads):
    flat_messages = []
    
    for thread in threads:
        if not thread:
            continue
            
        root_msg = thread[0]
        root_msg_id = root_msg['id']
        root_msg_key = f"{root_msg['chat_id']}_{root_msg['id']}"
        
        for msg in thread:
            msg_dict = msg.copy()
            msg_dict['root_msg_id'] = int(root_msg_id)
            msg_dict['root_msg_key'] = root_msg_key
            flat_messages.append(msg_dict)
    
    # Convert to DataFrame
    df = pd.DataFrame(flat_messages)
    
    # Convert datetime and sort
    df['messagedatetime'] = pd.to_datetime(df['messagedatetime'])
    df = df.sort_values('messagedatetime')
    
    return df

# %%
flattened = flatten_threads_to_df(threads)
flattened
# Out:
#             chat_id        id                           chat_name     peer_id  \
# 422308   1425154261      9257  https://t.me/incident_kuzbass_chat  1425154261
# 422309   1425154261      9260  https://t.me/incident_kuzbass_chat  1425154261
# 422310   1425154261      9261  https://t.me/incident_kuzbass_chat  1425154261
# 422311   1425154261      9264  https://t.me/incident_kuzbass_chat  1425154261
# 422312   1425154261      9265  https://t.me/incident_kuzbass_chat  1425154261
# ...             ...       ...                                 ...         ...
# 1918936  1366415996  19037325             https://t.me/readovchat  1366415996
# 1918937  1366415996  19037326             https://t.me/readovchat  1366415996
# 89956    1366415996  19037327             https://t.me/readovchat  1366415996
# 1918868  1366415996  19037328             https://t.me/readovchat  1366415996
# 675547   1425154261   1189323  https://t.me/incident_kuzbass_chat  1425154261
#
#             messagedatetime messagedate  \
# 422308  2021-01-01 00:30:21  2021-01-01
# 422309  2021-01-01 02:25:55  2021-01-01
# 422310  2021-01-01 03:24:14  2021-01-01
# 422311  2021-01-01 03:35:29  2021-01-01
# 422312  2021-01-01 03:40:17  2021-01-01
# ...                     ...         ...
# 1918936 2024-12-16 09:19:38  2024-12-16
# 1918937 2024-12-16 09:19:41  2024-12-16
# 89956   2024-12-16 09:19:45  2024-12-16
# 1918868 2024-12-16 09:19:55  2024-12-16
# 675547  2024-12-16 09:20:02  2024-12-16
#
#                                                messagetext out mentioned  \
# 422308                                     С Новым Годом 🎆   f         f
# 422309                                               Супер   f         f
# 422310                 https://vk.com/wall-61492440_772195   f         f
# 422311                                                   👍   f         f
# 422312                                                  👍👍   f         f
# ...                                                    ...  ..       ...
# 1918936                    Огромное уважение Бастрыкину!!!   f         f
# 1918937                               В расход этих чурок!   f         f
# 89956    А давайте в честь «дня конституции» перепишем ...   f         f
# 1918868                Капитализм для России это её закат.   f         f
# 675547                          Это с их странички в вк)))   f         f
#
#         media_unread  ... ttl_period quick_reply_shortcut_id effect factcheck  \
# 422308             f  ...
# 422309             f  ...
# 422310             f  ...
# 422311             f  ...
# 422312             f  ...
# ...              ...  ...        ...                     ...    ...       ...
# 1918936            f  ...
# 1918937            f  ...
# 89956              f  ...
# 1918868            f  ...
# 675547             f  ...
#
#         views forwards replies reactions root_msg_id         root_msg_key
# 422308   4049        5       1                  9257      1425154261_9257
# 422309      0        0       0                  9257      1425154261_9257
# 422310   4066        1       6                  9261      1425154261_9261
# 422311      0        0       0                  9261      1425154261_9261
# 422312      0        0       0                  9261      1425154261_9261
# ...       ...      ...     ...       ...         ...                  ...
# 1918936     0        0       0              19037203  1366415996_19037203
# 1918937     0        0       0              19037203  1366415996_19037203
# 89956       0        0       0              18998486  1366415996_18998486
# 1918868     0        0       0              19036851  1366415996_19036851
# 675547      0        0       0               1189296   1425154261_1189296
#
# [1918940 rows x 42 columns]

# %%
classified_comm = pd.read_csv("msg_comm.csv")
classified_comm
# Out:
#           id                                        messagetext     chat_id  \
# 0        932  Кировский район - сообщают о прилетах. \nПодро...  1759624775
# 1        934  Сообщают о попадании в 14-этажку на Текстильщи...  1759624775
# 2        935  Еще фото с Текстильщика\n\nПодписаться на ново...  1759624775
# 3        939  Фото более лучшего качества\n\nПодписаться на ...  1759624775
# 4        942  После обстрела вновь горит рынок.\n\nПодписать...  1759624775
# ...      ...                                                ...         ...
# 2614411  922  Здравствуйте, как с пешой очередью сегодня на ...  1781039971
# 2614412  925  Ночью было нанесено несколько ракетных ударов ...  1759624775
# 2614413  928  А как чужой по сути человек мог взять кредит н...  1781039971
# 2614414  929  За сутки из Мариуполя эвакуированы 400 человек...  1759624775
# 2614415  930  Одна половина Мариуполя парады проводит,песни ...  1759624775
#
#                                        chat_name      messagedatetime  \
# 0                        https://t.me/svodkadnrr  2022-05-10 07:22:24
# 1                        https://t.me/svodkadnrr  2022-05-10 07:30:59
# 2                        https://t.me/svodkadnrr  2022-05-10 07:34:04
# 3                        https://t.me/svodkadnrr  2022-05-10 07:40:45
# 4                        https://t.me/svodkadnrr  2022-05-10 07:42:47
# ...                                          ...                  ...
# 2614411  https://t.me/kpp_granica_Donbass_Russia  2022-03-30 05:25:42
# 2614412                  https://t.me/svodkadnrr  2022-05-10 05:52:01
# 2614413  https://t.me/kpp_granica_Donbass_Russia  2022-03-30 06:26:14
# 2614414                  https://t.me/svodkadnrr  2022-05-10 06:48:18
# 2614415                  https://t.me/svodkadnrr  2022-05-10 06:51:11
#
#          denazificationofukraine_similarity  \
# 0                                  0.363518
# 1                                  0.278069
# 2                                  0.350864
# 3                                  0.358291
# 4                                  0.382616
# ...                                     ...
# 2614411                            0.247597
# 2614412                            0.436001
# 2614413                            0.274786
# 2614414                            0.341952
# 2614415                            0.435843
#
#          protectionofrussianspeakers_similarity  \
# 0                                      0.412733
# 1                                      0.319513
# 2                                      0.333533
# 3                                      0.352816
# 4                                      0.365554
# ...                                         ...
# 2614411                                0.226825
# 2614412                                0.470060
# 2614413                                0.248637
# 2614414                                0.316086
# 2614415                                0.450479
#
#          natoexpansionthreat_similarity  biolabsconspiracy_similarity  \
# 0                              0.379205                      0.403658
# 1                              0.280388                      0.342343
# 2                              0.299367                      0.328005
# 3                              0.347029                      0.366997
# 4                              0.322637                      0.337853
# ...                                 ...                           ...
# 2614411                        0.265796                      0.258914
# 2614412                        0.414805                      0.438662
# 2614413                        0.267289                      0.296820
# 2614414                        0.249141                      0.286218
# 2614415                        0.392276                      0.400586
#
#          ukraineasafailedstate_similarity  \
# 0                                0.313252
# 1                                0.313447
# 2                                0.344438
# 3                                0.350818
# 4                                0.357958
# ...                                   ...
# 2614411                          0.258335
# 2614412                          0.395387
# 2614413                          0.266521
# 2614414                          0.330619
# 2614415                          0.453617
#
#          historicalunityofrussiaandukraine_similarity  \
# 0                                            0.359169
# 1                                            0.292393
# 2                                            0.317094
# 3                                            0.333356
# 4                                            0.298005
# ...                                               ...
# 2614411                                      0.267445
# 2614412                                      0.354262
# 2614413                                      0.252125
# 2614414                                      0.225762
# 2614415                                      0.438501
#
#          westernrussophobia_similarity  sanctionsaseconomicwarfare_similarity  \
# 0                             0.295160                               0.318650
# 1                             0.279550                               0.313060
# 2                             0.287007                               0.345397
# 3                             0.321616                               0.346255
# 4                             0.306774                               0.387792
# ...                                ...                                    ...
# 2614411                       0.246913                               0.244302
# 2614412                       0.366362                               0.417695
# 2614413                       0.321180                               0.289524
# 2614414                       0.217861                               0.193487
# 2614415                       0.380740                               0.376604
#
#          legitimizationofannexedterritories_similarity  \
# 0                                             0.406319
# 1                                             0.222745
# 2                                             0.313375
# 3                                             0.327540
# 4                                             0.347808
# ...                                                ...
# 2614411                                       0.192740
# 2614412                                       0.292731
# 2614413                                       0.234644
# 2614414                                       0.237640
# 2614415                                       0.415350
#
#          discreditingukrainianleadership_similarity
# 0                                          0.344065
# 1                                          0.288536
# 2                                          0.360459
# 3                                          0.376537
# 4                                          0.364824
# ...                                             ...
# 2614411                                    0.264145
# 2614412                                    0.428731
# 2614413                                    0.312083
# 2614414                                    0.276436
# 2614415                                    0.392697
#
# [2614416 rows x 15 columns]

# %%
# First ensure the join columns are of the same type in both dataframes
flattened['chat_id'] = flattened['chat_id'].astype('Int64')
flattened['id'] = flattened['id'].astype('Int64')
flattened['root_msg_id'] = flattened['root_msg_id'].astype('Int64')
classified_comm['chat_id'] = classified_comm['chat_id'].astype('Int64')
classified_comm['id'] = classified_comm['id'].astype('Int64')

# Perform the merge for replies with specific handling of duplicate columns
joined_df = flattened.merge(
    classified_comm,
    left_on=['chat_id', 'root_msg_id'],
    right_on=['chat_id', 'id'],
    how='left',
    suffixes=('', '_y')  # keep left table column names, add _y to right table duplicates
)

# Drop the duplicate columns with _y suffix (as we want to keep the original columns)
duplicate_cols = [col for col in joined_df.columns if col.endswith('_y')]
joined_df = joined_df.drop(columns=duplicate_cols)

# %%
joined_df
# Out:
#             chat_id        id                           chat_name     peer_id  \
# 0        1425154261      9257  https://t.me/incident_kuzbass_chat  1425154261
# 1        1425154261      9260  https://t.me/incident_kuzbass_chat  1425154261
# 2        1425154261      9261  https://t.me/incident_kuzbass_chat  1425154261
# 3        1425154261      9264  https://t.me/incident_kuzbass_chat  1425154261
# 4        1425154261      9265  https://t.me/incident_kuzbass_chat  1425154261
# ...             ...       ...                                 ...         ...
# 1918935  1366415996  19037325             https://t.me/readovchat  1366415996
# 1918936  1366415996  19037326             https://t.me/readovchat  1366415996
# 1918937  1366415996  19037327             https://t.me/readovchat  1366415996
# 1918938  1366415996  19037328             https://t.me/readovchat  1366415996
# 1918939  1425154261   1189323  https://t.me/incident_kuzbass_chat  1425154261
#
#             messagedatetime messagedate  \
# 0       2021-01-01 00:30:21  2021-01-01
# 1       2021-01-01 02:25:55  2021-01-01
# 2       2021-01-01 03:24:14  2021-01-01
# 3       2021-01-01 03:35:29  2021-01-01
# 4       2021-01-01 03:40:17  2021-01-01
# ...                     ...         ...
# 1918935 2024-12-16 09:19:38  2024-12-16
# 1918936 2024-12-16 09:19:41  2024-12-16
# 1918937 2024-12-16 09:19:45  2024-12-16
# 1918938 2024-12-16 09:19:55  2024-12-16
# 1918939 2024-12-16 09:20:02  2024-12-16
#
#                                                messagetext out mentioned  \
# 0                                          С Новым Годом 🎆   f         f
# 1                                                    Супер   f         f
# 2                      https://vk.com/wall-61492440_772195   f         f
# 3                                                        👍   f         f
# 4                                                       👍👍   f         f
# ...                                                    ...  ..       ...
# 1918935                    Огромное уважение Бастрыкину!!!   f         f
# 1918936                               В расход этих чурок!   f         f
# 1918937  А давайте в честь «дня конституции» перепишем ...   f         f
# 1918938                Капитализм для России это её закат.   f         f
# 1918939                         Это с их странички в вк)))   f         f
#
#         media_unread  ... denazificationofukraine_similarity  \
# 0                  f  ...                           0.248484
# 1                  f  ...                           0.248484
# 2                  f  ...                           0.352747
# 3                  f  ...                           0.352747
# 4                  f  ...                           0.352747
# ...              ...  ...                                ...
# 1918935            f  ...                           0.523125
# 1918936            f  ...                           0.523125
# 1918937            f  ...                           0.331993
# 1918938            f  ...                           0.298019
# 1918939            f  ...                                NaN
#
#         protectionofrussianspeakers_similarity natoexpansionthreat_similarity  \
# 0                                     0.238593                       0.258281
# 1                                     0.238593                       0.258281
# 2                                     0.339243                       0.324333
# 3                                     0.339243                       0.324333
# 4                                     0.339243                       0.324333
# ...                                        ...                            ...
# 1918935                               0.438542                       0.422893
# 1918936                               0.438542                       0.422893
# 1918937                               0.345232                       0.454705
# 1918938                               0.320316                       0.373239
# 1918939                                    NaN                            NaN
#
#         biolabsconspiracy_similarity ukraineasafailedstate_similarity  \
# 0                           0.262504                         0.297790
# 1                           0.262504                         0.297790
# 2                           0.411720                         0.354364
# 3                           0.411720                         0.354364
# 4                           0.411720                         0.354364
# ...                              ...                              ...
# 1918935                     0.460579                         0.441534
# 1918936                     0.460579                         0.441534
# 1918937                     0.384908                         0.423526
# 1918938                     0.329573                         0.364779
# 1918939                          NaN                              NaN
#
#         historicalunityofrussiaandukraine_similarity  \
# 0                                           0.304303
# 1                                           0.304303
# 2                                           0.367370
# 3                                           0.367370
# 4                                           0.367370
# ...                                              ...
# 1918935                                     0.385835
# 1918936                                     0.385835
# 1918937                                     0.475257
# 1918938                                     0.335376
# 1918939                                          NaN
#
#         westernrussophobia_similarity sanctionsaseconomicwarfare_similarity  \
# 0                            0.279074                              0.289715
# 1                            0.279074                              0.289715
# 2                            0.398487                              0.344885
# 3                            0.398487                              0.344885
# 4                            0.398487                              0.344885
# ...                               ...                                   ...
# 1918935                      0.419815                              0.397494
# 1918936                      0.419815                              0.397494
# 1918937                      0.432255                              0.370228
# 1918938                      0.391228                              0.335410
# 1918939                           NaN                                   NaN
#
#         legitimizationofannexedterritories_similarity  \
# 0                                            0.278389
# 1                                            0.278389
# 2                                            0.314726
# 3                                            0.314726
# 4                                            0.314726
# ...                                               ...
# 1918935                                      0.418509
# 1918936                                      0.418509
# 1918937                                      0.504351
# 1918938                                      0.345269
# 1918939                                           NaN
#
#         discreditingukrainianleadership_similarity
# 0                                         0.252699
# 1                                         0.252699
# 2                                         0.346028
# 3                                         0.346028
# 4                                         0.346028
# ...                                            ...
# 1918935                                   0.477528
# 1918936                                   0.477528
# 1918937                                   0.352893
# 1918938                                   0.308118
# 1918939                                        NaN
#
# [1918940 rows x 52 columns]

# %%
density = joined_df.resample(f'5min', on='messagedatetime').agg({'denazificationofukraine_similarity': 'sum'})

# %%
plt.figure(figsize=(15, 7))

plt.plot(density, '-', linewidth=2)

plt.title(f'"Denazification of Ukraine" Narrative Density Over Time')
plt.xlabel('Time')
plt.ylabel('Topic density')
plt.grid(True, linestyle='--', alpha=0.7)
plt.gcf().autofmt_xdate()
plt.tight_layout()

# %%
plt.figure(figsize=(15, 7))

plt.plot(density[-3500:], '-', linewidth=2)

plt.title(f'"Denazification of Ukraine" Narrative Density Over Time')
plt.xlabel('Time')
plt.ylabel('Topic density')
plt.grid(True, linestyle='--', alpha=0.7)
plt.gcf().autofmt_xdate()
plt.tight_layout()
