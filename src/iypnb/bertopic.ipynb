# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
from deep_translator import GoogleTranslator

def translate(x):
    try:
        tranlsation = GoogleTranslator(source='auto', target='en').translate(x)
    except:
        tranlsation = ""
    return tranlsation


df = pd.read_csv("../../data/telegram/telegram.csv")
df= df.sample(10_000)
df['englishMessageText'] = df.messageText.apply(lambda x: translate(x))

docs = df.englishMessageText.fillna("").values.tolist()

topic_model = BERTopic(language="multilingual")
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()
# Out:
#      Topic  Count                                     Name  \
# 0       -1   5205                         -1_the_of_and_in
# 1        0    229                   0_drone_drones_uav_air
# 2        1    191          1_channel_telegram_channels_you
# 3        2    187                 2_plus_sorry_ameram_stew
# 4        3    179           3_forces_armed_enemy_direction
# ..     ...    ...                                      ...
# 120    119     10  119_war_counteroffensive_will_ukrainian
# 121    120     10  120_advertising_pamirs_cannibals_monaco
# 122    121     10             121_mamut_meduza_business_he
# 123    122     10         122_islands_japanese_japan_kuril
# 124    123     10           123_vpk_armored_tanks_vehicles
#
#                                         Representation  \
# 0      [the, of, and, in, to, is, that, for, on, with]
# 1    [drone, drones, uav, air, defense, kamikaze, o...
# 2    [channel, telegram, channels, you, media, bloc...
# ...

# %%
topic_model.get_document_info(docs)
# Out:
#                                                Document  Topic  \
# 0     ⚡️On Pushkinskaya, riot police used flash-bang...     -1
# 1     "Maybe if I see the ballet Swan Lake on all ch...     71
# 2     📹People's Front delivered cargo from Denis Mai...     -1
# 3     ❗️Good news confirmed by the Ukrainian side - ...     -1
# 4     ​​♦️In just one week, THIRTY-FIVE ceasefire vi...     26
# ...                                                 ...    ...
# 9995  ‼️🇷🇺💪DPR Army occupied more Ukrainian Armed Fo...     65
# 9996  ⭐️🕙⭐️Statement by the official representative ...     26
# 9997  I came across a phrase in the feed that reflec...     86
# 9998  YOUTH\n\nThe Molodist restaurant has finally o...     -1
# 9999  Summary for the morning of April 19.\n\n2,333,...      5
#
#                                              Name  \
# 0                                -1_the_of_and_in
# 1     71_athletes_championship_paintball_tarasova
# 2                                -1_the_of_and_in
# ...
